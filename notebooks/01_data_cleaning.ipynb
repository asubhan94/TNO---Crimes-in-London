# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r'C:\Users\Tesla Laptops\Desktop\Job planning\Portfolio Project\TNO - Crimes in London\data\raw\M1045_MonthlyCrimeDashboard_TNOCrimeData.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Month_Year Area Type           Borough_SNT             Area name  \
# 0  01/06/2021   Borough  Barking and Dagenham  Barking and Dagenham
# 1  01/06/2021   Borough  Barking and Dagenham  Barking and Dagenham
# 2  01/06/2021   Borough  Barking and Dagenham  Barking and Dagenham
# 3  01/06/2021   Borough  Barking and Dagenham  Barking and Dagenham
# 4  01/06/2021   Borough  Barking and Dagenham  Barking and Dagenham
#
#    Area code              Offence Group                   Offence Subgroup  \
# 0  E09000002                   BURGLARY  BURGLARY - BUSINESS AND COMMUNITY
# 1  E09000002                   BURGLARY             BURGLARY - RESIDENTIAL
# 2  E09000002  ARSON AND CRIMINAL DAMAGE                    CRIMINAL DAMAGE
# 3  E09000002              DRUG OFFENCES               TRAFFICKING OF DRUGS
# 4  E09000002      PUBLIC ORDER OFFENCES        OTHER OFFENCES PUBLIC ORDER
#
#              Measure Financial Year FY_FYIndex  Count Refresh Date
# ...

# %%
df.shape
# Out:
# (791224, 12)

# %%
df.columns
# Out:
# Index(['Month_Year', 'Area Type', 'Borough_SNT', 'Area name', 'Area code',
#        'Offence Group', 'Offence Subgroup', 'Measure', 'Financial Year',
#        'FY_FYIndex', 'Count', 'Refresh Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 791224 entries, 0 to 791223
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Month_Year        791224 non-null  object
#  1   Area Type         791224 non-null  object
#  2   Borough_SNT       791224 non-null  object
#  3   Area name         790599 non-null  object
#  4   Area code         788005 non-null  object
#  5   Offence Group     791224 non-null  object
#  6   Offence Subgroup  791224 non-null  object
#  7   Measure           791224 non-null  object
#  8   Financial Year    791224 non-null  object
#  9   FY_FYIndex        791224 non-null  object
#  10  Count             791224 non-null  int64
#  11  Refresh Date      791224 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 72.4+ MB

# %%
df.isnull().sum()
# Out:
# Month_Year             0
# Area Type              0
# Borough_SNT            0
# Area name            625
# Area code           3219
# Offence Group          0
# Offence Subgroup       0
# Measure                0
# Financial Year         0
# FY_FYIndex             0
# Count                  0
# Refresh Date           0
# dtype: int64

# %%
df['Month_Year'] = pd.to_datetime(df['Month_Year'], dayfirst=True)
df['Refresh Date'] = pd.to_datetime(df['Refresh Date'], dayfirst=True)

# %%
df['Area Type'].unique()
# Out:
# array(['Borough', 'Safer Neighbourhood Teams'], dtype=object)

# %%
df['Measure'].unique()
# Out:
# array(['Positive Outcomes', 'Offences'], dtype=object)

# %%
df[df['Borough_SNT'] != df['Area name']]
# Out:
#        Month_Year                  Area Type             Borough_SNT  \
# 871    2021-06-01                    Borough                     N/K
# 872    2021-06-01                    Borough                     N/K
# 882    2021-06-01                    Borough                     N/K
# 883    2021-06-01                    Borough                     N/K
# 886    2021-06-01                    Borough                     N/K
# ...           ...                        ...                     ...
# 791219 2025-05-01  Safer Neighbourhood Teams  Westminster Westbourne
# 791220 2025-05-01  Safer Neighbourhood Teams  Westminster Westbourne
# 791221 2025-05-01  Safer Neighbourhood Teams  Westminster Westbourne
# 791222 2025-05-01  Safer Neighbourhood Teams  Westminster Westbourne
# 791223 2025-05-01  Safer Neighbourhood Teams  Westminster Westbourne
#
#          Area name  Area code                Offence Group  \
# 871     Other / NK        NaN    ARSON AND CRIMINAL DAMAGE
# ...

# %%
# Unique mismatch combination
df[df['Borough_SNT'] != df['Area name']][['Borough_SNT', 'Area name']].drop_duplicates()
# Out:
#                                    Borough_SNT  \
# 871                                        N/K
# 1365                Barking and Dagenham Abbey
# 1375               Barking and Dagenham Alibon
# 1380    Barking and Dagenham Barking Riverside
# 1383                 Barking and Dagenham Beam
# ...                                        ...
# 619938               Hounslow Hounslow Central
# 626998                    Lambeth Clapham Town
# 671592         Camden St Pancras & Somers Town
# 771404              Westminster Vincent Square
# 783416                    Ealing Acton Central
#
#                                     Area name
# 871                                Other / NK
# 1365                                    Abbey
# 1375                                   Alibon
# 1380                        Barking Riverside
# 1383                                     Beam
# ...                                       ...
# 619938          Hounslow Central (NOT ACTIVE)
# ...

# %%
df['Borough_SNT'].unique()
# Out:
# array(['Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington and Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'N/K',
#        'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Other / NK', 'Waltham Forest',
#        'Wandsworth', 'Westminster', 'Barking and Dagenham Abbey',
#        'Barking and Dagenham Alibon',
#        'Barking and Dagenham Barking Riverside',
#        'Barking and Dagenham Beam', 'Barking and Dagenham Becontree',
#        'Barking and Dagenham Chadwell Heath',
#        'Barking and Dagenham Eastbrook & Rush Green',
#        'Barking and Dagenham Eastbury', 'Barking and Dagenham Gascoigne',
#        'Barking and Dagenham Goresbrook', 'Barking and Dagenham Heath',
# ...

# %%
df['Area name'].unique()
# Out:
# array(['Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington and Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton',
#        'Other / NK', 'Newham', 'Redbridge', 'Richmond upon Thames',
#        'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest',
#        'Wandsworth', 'Westminster', 'Abbey', 'Alibon',
#        'Barking Riverside', 'Beam', 'Becontree', 'Chadwell Heath',
#        'Eastbrook & Rush Green', 'Eastbury', 'Gascoigne', 'Goresbrook',
#        'Heath', 'Longbridge', 'Mayesbrook', 'Northbury', 'Parsloes',
#        'Thames View', 'Valence', 'Village', 'Whalebone', 'Barnet Vale',
#        'Brunswick Park', 'Burnt Oak', 'Childs Hill', 'Colindale North',
#        'Colindale South', 'Cricklewood', 'East Barnet', 'East Finchley',
# ...

# %%
df['Borough_SNT'].nunique(), df['Area name'].nunique()
# Out:
# (720, 728)

# %%
df[df['Area name'].isnull()]['Borough_SNT'].head()
# Out:
# 448908    Other / NK
# 448911    Other / NK
# 452077    Other / NK
# 452078    Other / NK
# 452082    Other / NK
# Name: Borough_SNT, dtype: object

# %%
df[df['Borough_SNT'] == 'N/K' ]['Area name'].unique()
# Out:
# array(['Other / NK'], dtype=object)

# %%
df['Area name'].isnull().sum()
# Out:
# 625

# %%
# 625 area values are null, where Borough_SNT is OTHER / NK

# %%
df[df['Area name'].isnull()].head()
# Out:
#        Month_Year                  Area Type Borough_SNT Area name Area code  \
# 448908 2024-02-01  Safer Neighbourhood Teams  Other / NK       NaN        -1
# 448911 2024-02-01  Safer Neighbourhood Teams  Other / NK       NaN        -1
# 452077 2024-02-01  Safer Neighbourhood Teams  Other / NK       NaN        -1
# 452078 2024-02-01  Safer Neighbourhood Teams  Other / NK       NaN        -1
# 452082 2024-02-01  Safer Neighbourhood Teams  Other / NK       NaN        -1
#
#                       Offence Group                   Offence Subgroup  \
# 448908  VIOLENCE AGAINST THE PERSON               VIOLENCE WITH INJURY
# 448911  VIOLENCE AGAINST THE PERSON            VIOLENCE WITHOUT INJURY
# 452077        PUBLIC ORDER OFFENCES  RACE OR RELIGIOUS AGG PUBLIC FEAR
# 452078              SEXUAL OFFENCES              OTHER SEXUAL OFFENCES
# 452082                        THEFT                      BICYCLE THEFT
#
#          Measure Financial Year FY_FYIndex  Count Refresh Date
# ...

# %%
df[df['Area name']=='Other / NK']['Borough_SNT'].unique()
# Out:
# array(['N/K', 'Other / NK', 'Aviation Security'], dtype=object)

# %%
# Same values of "Borough_SNT" is filled where "Area name" is null because it contain "Other / NK" value only

# %%
df['Area name'] = df['Area name'].fillna(df['Borough_SNT'])

# %%
df.isnull().sum()
# Out:
# Month_Year             0
# Area Type              0
# Borough_SNT            0
# Area name              0
# Area code           3219
# Offence Group          0
# Offence Subgroup       0
# Measure                0
# Financial Year         0
# FY_FYIndex             0
# Count                  0
# Refresh Date           0
# dtype: int64

# %%
df['Area code'].unique()
# Out:
# array(['E09000002', 'E09000003', 'E09000004', 'E09000005', 'E09000006',
#        'E09000007', 'E09000008', 'E09000009', 'E09000010', 'E09000011',
#        'E09000012', 'E09000013', 'E09000014', 'E09000015', 'E09000016',
#        'E09000017', 'E09000018', 'E09000019', 'E09000020', 'E09000021',
#        'E09000022', 'E09000023', 'E09000024', nan, 'E09000025',
#        'E09000026', 'E09000027', 'E09000028', 'E09000029', 'E09000030',
#        'E09000031', 'E09000032', 'E09000033', 'E05014053', 'E05014054',
#        'E05014055', 'E05014056', 'E05014057', 'E05014058', 'E05014059',
#        'E05014060', 'E05014061', 'E05014062', 'E05014063', 'E05014064',
#        'E05014065', 'E05014066', 'E05014067', 'E05014068', 'E05014069',
#        'E05014070', 'E05014071', 'E05013628', 'E05013629', 'E05013630',
#        'E05013631', 'E05013632', 'E05013633', 'E05013634', 'E05013635',
#        'E05013636', 'E05013637', 'E05013638', 'E05013639', 'E05013640',
# ...

# %%
# Area code contain null, "N/K", "-1" and "NON ATHENA FORCE"

# %%
df['Area code'].value_counts().loc[['N/K', '-1', 'NON ATHENA FORCE',]]
# Out:
# Area code
# N/K                 1674
# -1                  1230
# NON ATHENA FORCE     434
# Name: count, dtype: int64

# %%
df['Area code'].isnull().sum()
# Out:
# 3219

# %%
# Check data type of columns
df.dtypes
# Out:
# Month_Year          datetime64[ns]
# Area Type                   object
# Borough_SNT                 object
# Area name                   object
# Area code                   object
# Offence Group               object
# Offence Subgroup            object
# Measure                     object
# Financial Year              object
# FY_FYIndex                  object
# Count                        int64
# Refresh Date        datetime64[ns]
# dtype: object

# %%
# Will leave it like this, if we need it further in solving problem then we'll see

# %%
df.to_csv(r'C:\Users\Tesla Laptops\Desktop\Job planning\Portfolio Project\TNO - Crimes in London\data\raw\M1045_MonthlyCrimeDashboard_TNOCrimeData_cleaned.csv', index=False)
